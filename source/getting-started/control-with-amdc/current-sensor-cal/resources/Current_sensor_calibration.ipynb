# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('exp_data.csv')

# %%
# Lets look at the imported experimental data file
df
# Out:
#    Reference Current [A]  Sensor Reading [V]
# 0                 -15.05               -4.62
# 1                 -10.11               -1.55
# 2                  -6.93                0.44
# 3                  -2.15                3.42
# 4                   0.00                4.70
# 5                   2.95                6.60
# 6                   6.06                8.53
# 7                   9.44               10.58

# %%
plt.plot(df['Reference Current [A]'], df['Sensor Reading [V]'], 'x')
plt.xlabel('Reference Current [A]')
plt.ylabel('Sensor Reading [V]')
# Out:
# Text(0, 0.5, 'Sensor Reading [V]')

# %%
# Lets fit a first order function to our experimental data
x= np.polyfit(df['Reference Current [A]'],df['Sensor Reading [V]'],1 );
fit = df['Reference Current [A]']*x[0] + x[1];

# %%
plt.plot(df['Reference Current [A]'], df['Sensor Reading [V]'], 'x')
plt.plot(df['Reference Current [A]'], fit)
plt.xlabel('Reference Current [A]')
plt.ylabel('Sensor Reading [V]')
plt.legend(['Raw data', 'Fit'])
